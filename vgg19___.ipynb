# %% [markdown]
# <a href="https://colab.research.google.com/github/RumeysaCeylan/ImageClassification/blob/main/vgg19___.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from keras.layers import Input, Lambda, Dense, Flatten
from keras.models import Model, load_model
from keras.applications.vgg19 import VGG19
from keras.applications.vgg19 import preprocess_input
from keras.preprocessing import image
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
import numpy as np
from glob import glob
import cv2
import matplotlib.pyplot as plt
from skimage.io import imread, imshow
from tensorflow.keras.preprocessing.image import load_img, img_to_array
from tqdm import tqdm


import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import skimage.io
import os 
import tqdm

import tensorflow 

from tqdm import tqdm
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split

from skimage.io import imread, imshow
from skimage.transform import resize
from skimage.color import grey2rgb



from keras.layers import InputLayer, BatchNormalization, Dropout, Flatten, Dense, Activation, MaxPool2D, Conv2D
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
train_datagen = ImageDataGenerator(rescale = 1./255,
                                   shear_range = 0.2,
                                   zoom_range = 0.2,
                                   horizontal_flip = True)

test_datagen = ImageDataGenerator(rescale = 1./255)

valid_datagen = ImageDataGenerator(rescale = 1./255)


# Make sure you provide the same target size as initialied for the image size
training_set = train_datagen.flow_from_directory('/content/drive/MyDrive/archive/Dataset',
                                                 target_size = (224, 224),
                                                 batch_size = 128,
                                                 class_mode = 'categorical')



valid_set = valid_datagen.flow_from_directory(directory = '/content/drive/MyDrive/archive/validation',
                                                  target_size = (224,224),
                                                  class_mode = 'categorical',
                                                  batch_size = 128)
     

test_set = test_datagen.flow_from_directory('/content/drive/MyDrive/archive/Test',
                                            target_size = (224, 224),
                                            batch_size = 128,
                                            class_mode = 'categorical')
# Out:
# Found 4030 images belonging to 4 classes.
# Found 1103 images belonging to 4 classes.
# Found 1281 images belonging to 4 classes.

# %%
fig, ax = plt.subplots(nrows = 1, ncols = 5, figsize=(20,20))

for i in tqdm(range(0,5)):
    rand1 = np.random.randint(len(training_set))
    rand2 = np.random.randint(100)
    ax[i].imshow(training_set[rand1][0][rand2])
    ax[i].axis('off')
    a = training_set[rand1][1][rand2]
    if a[0] == 1:
        ax[i].set_title('Mild Dementia')
    elif a[1] == 1:
        ax[i].set_title('Moderate Dementia')
    elif a[2] == 1:
        ax[i].set_title('Non Dementia')
    elif a[3] == 1:
        ax[i].set_title('Very Mild Dementia')
# Out:
# 100%|██████████| 5/5 [01:55<00:00, 23.03s/it]

# %%
IMAGE_SIZE = [224, 224]
vgg = VGG19(input_shape=IMAGE_SIZE + [3], weights='imagenet', include_top=False)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg19/vgg19_weights_tf_dim_ordering_tf_kernels_notop.h5
# 80134624/80134624 [==============================] - 0s 0us/step

# %%
for layer in vgg.layers:
  layer.trainable = False

# %%
x = Flatten()(vgg.output)

# %%
folders=glob("/content/drive/MyDrive/archive/Dataset/*")
folders
prediction = Dense(len(folders), activation='softmax')(x)
 
# creating a model object
model = Model(inputs=vgg.input, outputs=prediction)

# %%
prediction = Dense(len(folders), activation='softmax')(x)
 
# creating a model object
model = Model(inputs=vgg.input, outputs=prediction)

# %%
model.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 112, 112, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 112, 112, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 112, 112, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv4 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv4 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 14, 14, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv4 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 7, 7, 512)         0
#
#  flatten (Flatten)           (None, 25088)             0
#
#  dense_1 (Dense)             (None, 4)                 100356
#
# =================================================================
# Total params: 20,124,740
# Trainable params: 100,356
# Non-trainable params: 20,024,384
# _________________________________________________________________

# %%
import tensorflow 

OPT    = tensorflow.keras.optimizers.Adam(learning_rate=0.001)

model.compile(loss='categorical_crossentropy',
              metrics=[tensorflow.keras.metrics.AUC(name = 'auc')],
              optimizer=OPT)

# %%
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
filepath = './content/drive/MyDrive/Colab Notebooks/best_weights.hdf5'

earlystopping = EarlyStopping(monitor = 'val_auc', 
                              mode = 'max' , 
                              patience = 15,
                              verbose = 1)

checkpoint    = ModelCheckpoint(filepath, 
                                monitor = 'val_auc', 
                                mode='max', 
                                save_best_only=True, 
                                verbose = 1)


callback_list = [earlystopping, checkpoint]

# %%
model.compile(
  loss='categorical_crossentropy',
  optimizer='adam',
  metrics=['accuracy']
)

# %%
from keras.preprocessing.image import ImageDataGenerator
# fiting the model
 
r = model.fit(
  training_set,
  validation_data=valid_set,
  epochs=50,
  steps_per_epoch=len(training_set),
  validation_steps=len(valid_set)
)
# Out:
# Epoch 1/50
# 32/32 [==============================] - 853s 26s/step - loss: 1.4229 - accuracy: 0.4814 - val_loss: 1.4718 - val_accuracy: 0.4071
# Epoch 2/50
# 32/32 [==============================] - 59s 2s/step - loss: 0.9353 - accuracy: 0.5767 - val_loss: 1.6397 - val_accuracy: 0.4062
# Epoch 3/50
# 32/32 [==============================] - 60s 2s/step - loss: 0.8136 - accuracy: 0.6310 - val_loss: 1.3908 - val_accuracy: 0.4089
# Epoch 4/50
# 32/32 [==============================] - 59s 2s/step - loss: 0.7667 - accuracy: 0.6538 - val_loss: 1.5508 - val_accuracy: 0.4071
# Epoch 5/50
# 32/32 [==============================] - 59s 2s/step - loss: 0.7264 - accuracy: 0.6749 - val_loss: 1.7569 - val_accuracy: 0.4062
# Epoch 6/50
# 32/32 [==============================] - 59s 2s/step - loss: 0.7042 - accuracy: 0.6938 - val_loss: 1.3424 - val_accuracy: 0.4470
# Epoch 7/50
# 32/32 [==============================] - 59s 2s/step - loss: 0.6751 - accuracy: 0.7020 - val_loss: 1.2286 - val_accuracy: 0.4406
# Epoch 8/50
# 32/32 [==============================] - 60s 2s/step - loss: 0.6357 - accuracy: 0.7295 - val_loss: 1.4119 - val_accuracy: 0.4261
# Epoch 9/50
# 32/32 [==============================] - 60s 2s/step - loss: 0.6148 - accuracy: 0.7449 - val_loss: 1.5316 - val_accuracy: 0.4189
# Epoch 10/50
# 32/32 [==============================] - 60s 2s/step - loss: 0.5923 - accuracy: 0.7459 - val_loss: 1.4786 - val_accuracy: 0.4252
# Epoch 11/50
# 32/32 [==============================] - 60s 2s/step - loss: 0.5917 - accuracy: 0.7511 - val_loss: 1.2019 - val_accuracy: 0.4814
# Epoch 12/50
# 32/32 [==============================] - 59s 2s/step - loss: 0.6139 - accuracy: 0.7404 - val_loss: 1.7409 - val_accuracy: 0.4125
# Epoch 13/50
# 32/32 [==============================] - 58s 2s/step - loss: 0.6017 - accuracy: 0.7382 - val_loss: 1.6962 - val_accuracy: 0.4270
# Epoch 14/50
# 32/32 [==============================] - 58s 2s/step - loss: 0.5676 - accuracy: 0.7551 - val_loss: 1.0378 - val_accuracy: 0.5612
# Epoch 15/50
# 32/32 [==============================] - 58s 2s/step - loss: 0.5249 - accuracy: 0.7801 - val_loss: 1.2351 - val_accuracy: 0.4841
# Epoch 16/50
# 32/32 [==============================] - 58s 2s/step - loss: 0.5124 - accuracy: 0.7958 - val_loss: 1.2088 - val_accuracy: 0.4887
# Epoch 17/50
# 32/32 [==============================] - 59s 2s/step - loss: 0.5121 - accuracy: 0.7973 - val_loss: 1.8757 - val_accuracy: 0.4252
# Epoch 18/50
# 32/32 [==============================] - 57s 2s/step - loss: 0.5388 - accuracy: 0.7725 - val_loss: 1.4383 - val_accuracy: 0.4569
# Epoch 19/50
# 32/32 [==============================] - 58s 2s/step - loss: 0.4973 - accuracy: 0.7958 - val_loss: 1.3196 - val_accuracy: 0.4787
# Epoch 20/50
# 32/32 [==============================] - 58s 2s/step - loss: 0.4765 - accuracy: 0.8102 - val_loss: 1.5154 - val_accuracy: 0.4560
# Epoch 21/50
# 32/32 [==============================] - 58s 2s/step - loss: 0.4900 - accuracy: 0.7955 - val_loss: 1.0378 - val_accuracy: 0.5621
# Epoch 22/50
# 32/32 [==============================] - 59s 2s/step - loss: 0.4677 - accuracy: 0.8159 - val_loss: 1.6264 - val_accuracy: 0.4488
# Epoch 23/50
# 32/32 [==============================] - 58s 2s/step - loss: 0.4633 - accuracy: 0.8226 - val_loss: 1.4262 - val_accuracy: 0.4841
# Epoch 24/50
# 32/32 [==============================] - 58s 2s/step - loss: 0.4421 - accuracy: 0.8377 - val_loss: 1.5081 - val_accuracy: 0.4687
# Epoch 25/50
# 32/32 [==============================] - 58s 2s/step - loss: 0.4338 - accuracy: 0.8367 - val_loss: 1.4761 - val_accuracy: 0.4832
# Epoch 26/50
# 32/32 [==============================] - 58s 2s/step - loss: 0.4320 - accuracy: 0.8295 - val_loss: 1.1929 - val_accuracy: 0.5267
# Epoch 27/50
# 32/32 [==============================] - 58s 2s/step - loss: 0.4322 - accuracy: 0.8315 - val_loss: 1.5018 - val_accuracy: 0.4760
# Epoch 28/50
# 32/32 [==============================] - 57s 2s/step - loss: 0.4253 - accuracy: 0.8340 - val_loss: 1.4895 - val_accuracy: 0.4814
# Epoch 29/50
# 32/32 [==============================] - 58s 2s/step - loss: 0.3996 - accuracy: 0.8536 - val_loss: 1.8939 - val_accuracy: 0.4424
# Epoch 30/50
# 32/32 [==============================] - 58s 2s/step - loss: 0.4051 - accuracy: 0.8486 - val_loss: 2.1341 - val_accuracy: 0.4270
# Epoch 31/50
# 32/32 [==============================] - 59s 2s/step - loss: 0.4027 - accuracy: 0.8469 - val_loss: 1.6967 - val_accuracy: 0.4606
# Epoch 32/50
# 32/32 [==============================] - 58s 2s/step - loss: 0.4147 - accuracy: 0.8404 - val_loss: 2.0998 - val_accuracy: 0.4297
# Epoch 33/50
# 32/32 [==============================] - 58s 2s/step - loss: 0.4093 - accuracy: 0.8337 - val_loss: 1.7981 - val_accuracy: 0.4578
# Epoch 34/50
# 32/32 [==============================] - 58s 2s/step - loss: 0.3836 - accuracy: 0.8514 - val_loss: 1.7897 - val_accuracy: 0.4506
# Epoch 35/50
# 32/32 [==============================] - 58s 2s/step - loss: 0.4023 - accuracy: 0.8437 - val_loss: 1.8528 - val_accuracy: 0.4597
# Epoch 36/50
# 32/32 [==============================] - 59s 2s/step - loss: 0.3822 - accuracy: 0.8558 - val_loss: 2.0669 - val_accuracy: 0.4361
# Epoch 37/50
# 32/32 [==============================] - 58s 2s/step - loss: 0.3707 - accuracy: 0.8566 - val_loss: 1.4219 - val_accuracy: 0.5014
# Epoch 38/50
# 32/32 [==============================] - 58s 2s/step - loss: 0.4016 - accuracy: 0.8397 - val_loss: 1.9979 - val_accuracy: 0.4560
# Epoch 39/50
# 32/32 [==============================] - 58s 2s/step - loss: 0.4330 - accuracy: 0.8191 - val_loss: 2.0411 - val_accuracy: 0.4442
# Epoch 40/50
# 32/32 [==============================] - 58s 2s/step - loss: 0.3600 - accuracy: 0.8692 - val_loss: 1.7580 - val_accuracy: 0.4751
# Epoch 41/50
# 32/32 [==============================] - 59s 2s/step - loss: 0.3506 - accuracy: 0.8702 - val_loss: 1.6746 - val_accuracy: 0.4823
# Epoch 42/50
# 32/32 [==============================] - 58s 2s/step - loss: 0.3414 - accuracy: 0.8804 - val_loss: 2.2203 - val_accuracy: 0.4406
# Epoch 43/50
# 32/32 [==============================] - 58s 2s/step - loss: 0.3820 - accuracy: 0.8479 - val_loss: 1.2956 - val_accuracy: 0.5539
# Epoch 44/50
# 32/32 [==============================] - 58s 2s/step - loss: 0.4027 - accuracy: 0.8342 - val_loss: 2.1218 - val_accuracy: 0.4424
# Epoch 45/50
# 32/32 [==============================] - 58s 2s/step - loss: 0.3631 - accuracy: 0.8596 - val_loss: 1.8684 - val_accuracy: 0.4624
# Epoch 46/50
# 32/32 [==============================] - 59s 2s/step - loss: 0.3491 - accuracy: 0.8682 - val_loss: 2.1601 - val_accuracy: 0.4515
# Epoch 47/50
# 32/32 [==============================] - 58s 2s/step - loss: 0.3870 - accuracy: 0.8457 - val_loss: 2.0568 - val_accuracy: 0.4524
# Epoch 48/50
# 32/32 [==============================] - 57s 2s/step - loss: 0.3539 - accuracy: 0.8556 - val_loss: 1.6184 - val_accuracy: 0.4914
# Epoch 49/50
# 32/32 [==============================] - 58s 2s/step - loss: 0.3281 - accuracy: 0.8787 - val_loss: 2.2065 - val_accuracy: 0.4515
# Epoch 50/50
# 32/32 [==============================] - 58s 2s/step - loss: 0.3375 - accuracy: 0.8715 - val_loss: 2.0655 - val_accuracy: 0.4533

# %%
plt.plot(r.history['loss'])
plt.plot(r.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left', bbox_to_anchor=(1,1))
plt.show()

# %%
# Test Case 1: Non-Dementia

dic = test_set.class_indices
idc = {k:v for v, k in dic.items()}

img = load_img('/content/drive/MyDrive/archive/Test/Non_Demented/non_105.jpg', target_size = (224,224,3))
img = img_to_array(img)
img = img/255
imshow(img)
plt.axis('off')
img = np.expand_dims(img,axis=0)
#answer = model.predict_classes(img)
answer = np.argmax(model.predict(img), axis=1)
#probability = round(np.max(model.predict_proba(img)*100),2)
probability=round(np.max(model.predict_on_batch(img)*100),2)
print(probability, '% chances are there that the image is',idc[answer[0]])
# Out:
# 1/1 [==============================] - 1s 865ms/step
# 99.91 % chances are there that the image is Non_Demented

# %%
# Test Case 1: mild-Dementia

dic = test_set.class_indices
idc = {k:v for v, k in dic.items()}

img = load_img('/content/drive/MyDrive/archive/Test/Very_Mild_Demented/verymild_112.jpg', target_size = (224,224,3))
img = img_to_array(img)
img = img/255
imshow(img)
plt.axis('off')
img = np.expand_dims(img,axis=0)
#answer = model.predict_classes(img)
answer = np.argmax(model.predict(img), axis=1)
#probability = round(np.max(model.predict_proba(img)*100),2)
probability=round(np.max(model.predict_on_batch(img)*100),2)
print(probability, '% chances are there that the image is',idc[answer[0]])
# Out:
# 1/1 [==============================] - 0s 21ms/step
# 61.83 % chances are there that the image is Very_Mild_Demented

# %%
# Test Case 1: mild-Dementia

dic = test_set.class_indices
idc = {k:v for v, k in dic.items()}

img = load_img('/content/drive/MyDrive/archive/Test/Non_Demented/non_128.jpg', target_size = (224,224,3))
img = img_to_array(img)
img = img/255
imshow(img)
plt.axis('off')
img = np.expand_dims(img,axis=0)
#answer = model.predict_classes(img)
answer = np.argmax(model.predict(img), axis=1)
#probability = round(np.max(model.predict_proba(img)*100),2)
probability=round(np.max(model.predict_on_batch(img)*100),2)
print(probability, '% chances are there that the image is',idc[answer[0]])
# Out:
# 1/1 [==============================] - 0s 27ms/step
# 90.53 % chances are there that the image is Non_Demented

# %%
# Test Case 1: mild-Dementia

dic = test_set.class_indices
idc = {k:v for v, k in dic.items()}

img = load_img('/content/drive/MyDrive/archive/Test/Mild_Demented/mild_113.jpg', target_size = (224,224,3))
img = img_to_array(img)
img = img/255
imshow(img)
plt.axis('off')
img = np.expand_dims(img,axis=0)
#answer = model.predict_classes(img)
answer = np.argmax(model.predict(img), axis=1)
#probability = round(np.max(model.predict_proba(img)*100),2)
probability=round(np.max(model.predict_on_batch(img)*100),2)
print(probability, '% chances are there that the image is',idc[answer[0]])
# Out:
# 1/1 [==============================] - 0s 20ms/step
# 69.79 % chances are there that the image is Very_Mild_Demented

# %%
# Test Case 1: mild-Dementia

dic = test_set.class_indices
idc = {k:v for v, k in dic.items()}

img = load_img('/content/drive/MyDrive/archive/Test/Mild_Demented/mild.jpg', target_size = (224,224,3))
img = img_to_array(img)
img = img/255
imshow(img)
plt.axis('off')
img = np.expand_dims(img,axis=0)
#answer = model.predict_classes(img)
answer = np.argmax(model.predict(img), axis=1)
#probability = round(np.max(model.predict_proba(img)*100),2)
probability=round(np.max(model.predict_on_batch(img)*100),2)
print(probability, '% chances are there that the image is',idc[answer[0]])
# Out:
# 1/1 [==============================] - 0s 21ms/step
# 73.8 % chances are there that the image is Mild_Demented

# %%
import tensorflow as tf
from keras.models import load_model
model.save('/content/drive/MyDrive/archive/models/vgg19alzheimer.h5')
